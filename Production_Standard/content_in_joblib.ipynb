# %%
import joblib

scaler = joblib.load(r"D:\CA_content\Python\Final_Project\hybrid_With_best_Score\Production_Standard\gru_price_scaler.joblib")

print(f"Type        : {type(scaler)}")
print(f"Class       : {scaler.__class__.__name__}")
print(f"Feature range: {scaler.feature_range}")
print(f"Data min    : {scaler.data_min_}")
print(f"Data max    : {scaler.data_max_}")
print(f"Scale_      : {scaler.scale_}")
print(f"Min_        : {scaler.min_}")
print(f"n_features  : {scaler.n_features_in_}")
print(f"n_samples   : {scaler.n_samples_seen_}")

print("\n--- Full scaler dict ---")
print(scaler.__dict__)
# Out:
# Type        : <class 'sklearn.preprocessing._data.MinMaxScaler'>
# Class       : MinMaxScaler
# Feature range: (0, 1)
# Data min    : [0.]
# Data max    : [7.853632]
# Scale_      : [0.12732962]
# Min_        : [0.]
# n_features  : 1
# n_samples   : 5833498
#
# --- Full scaler dict ---
# {'feature_range': (0, 1), 'copy': True, 'clip': False, 'feature_names_in_': array(['log_price'], dtype=object), 'n_features_in_': 1, 'n_samples_seen_': 5833498, 'scale_': array([0.12732962]), 'min_': array([0.]), 'data_min_': array([0.]), 'data_max_': array([7.853632]), 'data_range_': array([7.853632])}
